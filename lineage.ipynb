# %%
import pandas as pd 
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('pmgenoma05jul2022.csv',sep='|')
df.columns = [col.lower() for col in df.columns]
print(df.shape)
df.head()
# Out:
# (19201, 15)
#   fecha_corte  uuid  fecha_muestra  edad       sexo  \
# 0    20220702   NaN     20210307.0  54.0  MASCULINO
# 1    20220702   NaN     20210616.0  46.0   FEMENINO
# 2    20220702   NaN     20210727.0  33.0   FEMENINO
# 3    20220702   NaN     20211022.0  26.0   FEMENINO
# 4    20220702   NaN     20211127.0  23.0  MASCULINO
#
#                            institucion  ubigeo_paciente departamento_paciente  \
# 0                    GOBIERNO REGIONAL         240102.0
# 1  DIRECCION DE RED INTEGRADA DE SALUD         140126.0                  LIMA
# 2                      MUNICIPALIDADES         140140.0                  LIMA
# 3  DIRECCION DE RED INTEGRADA DE SALUD         140135.0                  LIMA
# 4  DIRECCION DE RED INTEGRADA DE SALUD         140106.0                  LIMA
#
#   provincia_paciente     distrito_paciente departamento_muestra  \
# 0             CALLAO            BELLAVISTA               CALLAO
# ...

# %% [markdown]
# #### Análisis de data - Dtypes, vacios, grupos de data

# %%
df.dtypes
# Out:
# fecha_corte               object
# uuid                     float64
# fecha_muestra            float64
# edad                     float64
# sexo                      object
# institucion               object
# ubigeo_paciente          float64
# departamento_paciente     object
# provincia_paciente        object
# distrito_paciente         object
# departamento_muestra      object
# provincia_muestra         object
# distrito_muestra          object
# tipo_muestra              object
# resultado                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# fecha_corte               0
# uuid                     33
# fecha_muestra             2
# edad                      5
# sexo                      2
# institucion               2
# ubigeo_paciente           2
# departamento_paciente     2
# provincia_paciente        2
# distrito_paciente         2
# departamento_muestra      2
# provincia_muestra         2
# distrito_muestra          2
# tipo_muestra              2
# resultado                 2
# dtype: int64

# %%
df.resultado.value_counts()
# Out:
# Linaje C.37           3676
# Linaje BA.1           2049
# Linaje BA.1.1         1688
# Linaje P.1            1229
# Linaje B.1.617.2      1150
# Linaje BA.2.12.1      1115
# Linaje BA.2           1068
# Linaje AY.39.2         798
# Linaje AY.102          549
# Linaje AY.122          442
# Linaje AY.4            359
# Linaje AY.39           359
# Linaje AY.43           308
# Linaje P.1.4           243
# Linaje BA.5            240
# Linaje B.1.621         234
# Linaje AY.25           206
# Linaje AY.119.1        203
# P.1.12                 202
# LINAJE BA.4            200
# BA.2.9                 200
# Linaje AY.100          157
# Linaje AY.20           134
# Linaje AY.3            134
# Linaje P.1.7           129
# Linaje AY.12           117
# Linaje BA.5.1          108
# Linaje AY.26           104
# Linaje AY.119           94
# Linaje BA.4.1           74
# Linaje B.1.1.348        69
# Linaje BA.2.3           68
# Linaje BA.2.12          65
# Linaje B.1.1            64
# ...
